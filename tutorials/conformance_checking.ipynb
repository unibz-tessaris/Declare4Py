# %% [markdown]
# # Conformance Checking in Declare4Py
#
# This tutorial explains how to perform the checking of a DECLARE model and how to browse the results.

# %%
import sys
import os
import pathlib

SCRIPT_DIR = pathlib.Path("..", "src").resolve()
sys.path.append(os.path.dirname(SCRIPT_DIR))

from src.declare4py.D4PyEventLog import D4PyEventLog
from src.declare4py.ProcessModels.DeclareModel import DeclareModel
from src.declare4py.ProcessModels.DeclareModel import DeclareModelTemplate

# %% [markdown]
# The DECLARE constraints supported by Declare4Py can be retrieved with the `get_unary_templates()` and `get_binary_templates` functions of the `DeclareModelTemplate` class:

# %%
unary_templates = DeclareModelTemplate.get_unary_templates()
binary_templates = DeclareModelTemplate.get_binary_templates()

print("Unary templates:")
print("-----------------")
for template in unary_templates:
    print(template.templ_str)
print("\n")

print("Binary templates:")
print("-----------------")
for template in binary_templates:
    print(template.templ_str)
# Out:
# Unary templates:
# -----------------
# Existence
# Absence
# Exactly
# Init
#
#
# Binary templates:
# -----------------
# Choice
# Exclusive Choice
# Responded Existence
# Response
# Alternate Response
# Chain Response
# Precedence
# Alternate Precedence
# Chain Precedence
# Succession
# Alternate Succession
# Co-Existence
# Chain Succession
# Not Chain Succession
# Not Co-Existence
# Not Succession
# Not Responded Existence
# Not Response
# Not Precedence
# Not Chain Response
# Not Chain Precedence

# %% [markdown]
# Notice that for the templates `Existence`, `Absence` and `Exactly` an additional parameter is necessary for the cardinality. This has to be encoded in the DECLARE `.decl` model with a numeric suffix, for example `Exactly2` or `Existence23`.
#
# The next step is the parsing of the log and of the DECLARE model.

# %%
log_path = os.path.join("..", "tests", "Sepsis Cases.xes.gz")

event_log = D4PyEventLog()
event_log.parse_xes_log(log_path)

model_path = os.path.join("..", "tests", "resource", "files", "declare", "data_model.decl")
decl_model = DeclareModel().parse_from_file(model_path)
# Out:
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]

# %% [markdown]
# The DECLARE model can be inspected by getting all the activity names or the constraints. This information is returned as a list of strings.

# %%
model_activities = decl_model.get_model_activities()
model_constraints = decl_model.get_decl_model_constraints()

print("Model activities:")
print("-----------------")
for idx, act in enumerate(model_activities):
    print(idx, act)
print("\n")

print("Model constraints:")
print("-----------------")
for idx, constr in enumerate(model_constraints):
    print(idx, constr)
# Out:
# Model activities:
# -----------------
# 0 ER Triage
# 1 ER Registration
# 2 ER Sepsis Triage
# 3 Leucocytes
# 4 CRP
# 5 LacticAcid
# 6 IV Antibiotics
# 7 Admission NC
# 8 IV Liquid
# 9 Release A
# 10 Return ER
# 11 Admission IC
#
#
# Model constraints:
# -----------------
# 0 Chain Response[ER Registration, ER Triage] |(A.DiagnosticArtAstrup is false) AND (A.SIRSCritHeartRate is true) AND (A.org:group is A) AND (A.DiagnosticBlood is true) AND (A.DisfuncOrg is false) AND (A.DiagnosticECG is true) AND (A.Age >= 45) AND (A.InfectionSuspected is true) AND (A.DiagnosticLacticAcid is true) AND (A.DiagnosticSputum is true) AND (A.Hypoxie is false) AND (A.DiagnosticUrinaryCulture is true) AND (A.DiagnosticLiquor is false) AND (A.SIRSCritTemperature is true) AND (A.Infusion is true) AND (A.Hypotensie is false) AND (A.DiagnosticUrinarySediment is true) AND (A.Oligurie is false) AND (A.Age <= 80) AND (A.SIRSCritTachypnea is true) AND (A.DiagnosticOther is false) AND (A.SIRSCritLeucos is false) AND (A.DiagnosticIC is true) AND (A.SIRSCriteria2OrMore is true) AND (A.DiagnosticXthorax is true) |T.org:group is C |52,2154,s
# 1 Existence2[Admission NC] | |
# 2 Chain Response[Admission NC, Release B] |A.org:group is K |T.org:group is E |
# 3 Chain Response[Admission NC, Release A] |A.org:group is I |T.org:group is E |133020,957701,s
# 4 Chain Precedence[IV Liquid, Admission NC] |A.org:group is I |T.org:group is A |92,14473,s
# 5 Chain Precedence[Release A, Return ER] |A.org:group is ? |T.org:group is E |1121801,1121801,s
# 6 Chain Precedence[ER Sepsis Triage, IV Antibiotics] |A.org:group is L |T.org:group is L |15,11000,s
# 7 Chain Response[ER Sepsis Triage, IV Antibiotics] |A.org:group is L |T.org:group is L |15,11000,s
# 8 Chain Precedence[Admission IC, Admission NC] |A.org:group is J |T.org:group is J |
# 9 Chain Precedence[IV Antibiotics, Admission NC] |A.org:group is F |T.org:group is A |92,14459,s
# 10 Chain Precedence[Admission NC, Release B] |A.org:group is E |T.org:group is K |48225,48225,s
# 11 Chain Response[Admission IC, Admission NC] |A.org:group is J |T.org:group is J |61534,61534,s
# 12 Chain Response[LacticAcid, Leucocytes] |A.LacticAcid <= 0.8 |T.Leucocytes >= 13.8 |0,2778,m
# 13 Chain Precedence[ER Registration, ER Triage] |A.org:group is C |(T.InfectionSuspected is true) AND (T.SIRSCritTemperature is true) AND (T.DiagnosticLacticAcid is true) AND (T.DiagnosticBlood is true) AND (T.DiagnosticIC is true) AND (T.SIRSCriteria2OrMore is true) AND (T.DiagnosticECG is true) |52,2154,s

# %% [markdown]
# After importing the Declare4Py package and specified the paths of the log and of the DECLARE model, a `BasicMPDeclareConformanceChecking` object has to be instantiated.

# %%
from src.declare4py.ProcessMiningTasks.DeclareConformanceChecking.MPDeclareAnalyzer import MPDeclareAnalyzer


basic_checker = MPDeclareAnalyzer(consider_vacuity=False, log=event_log, declare_model=decl_model)
conf_check_res = basic_checker.run()
# Out:
# 0 {'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1 {'attributes': {'concept:name': 'B'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 21, 11, 4, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 26, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 2 {'attributes': {'concept:name': 'C'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 9, 19, 29, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 15, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 3 {'attributes': {'concept:name': 'D'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 7, 10, 11, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 7, 28, 17, 36, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 4 {'attributes': {'concept:name': 'E'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2015, 1, 15, 20, 14, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Antibiotics', 'time:timestamp': datetime.datetime(2015, 1, 15, 20, 35, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 5 {'attributes': {'concept:name': 'F'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 7, 18, 56, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 9, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 6 {'attributes': {'concept:name': 'G'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 9, 5, 14, 40, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'F', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 12, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 7 {'attributes': {'concept:name': 'H'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 3, 11, 9, 50, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release B', 'time:timestamp': datetime.datetime(2014, 3, 16, 1, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 8 {'attributes': {'concept:name': 'I'}, 'events': [{'InfectionSuspected': True, 'org:group': 'L', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 11, 9, 9, 21, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'H', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 16, 13, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 9 {'attributes': {'concept:name': 'J'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 2, 16, 45, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 6, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 10 {'attributes': {'concept:name': 'K'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 23, 21, 43, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'I', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 6, 10, 22, 27, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 11 {'attributes': {'concept:name': 'L'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 8, 31, 18, 47, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'J', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 9, 12, 0, 40, 27, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 12 {'attributes': {'concept:name': 'M'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 10, 3, 8, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 10, 10, 3, 10, 54, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 13 {'attributes': {'concept:name': 'N'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 6, 16, 10, 34, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'K', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': False}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 21, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 14 {'attributes': {'concept:name': 'O'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 30, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 11, 22, 29, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 10, 17, 18, 40, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 15 {'attributes': {'concept:name': 'P'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 20, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 22, 9, 39, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 4, 22, 11, 1, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 16 {'attributes': {'concept:name': 'Q'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2013, 12, 15, 14, 17, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2013, 12, 15, 14, 19, 7, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 17 {'attributes': {'concept:name': 'R'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 30, 12, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'Leucocytes': 9.1, 'org:group': 'B', 'lifecycle:transition': 'complete', 'concept:name': 'Leucocytes', 'time:timestamp': datetime.datetime(2014, 11, 30, 12, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 18 {'attributes': {'concept:name': 'S'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 21, 12, 16, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 8, 30, 14, 54, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 19 {'attributes': {'concept:name': 'T'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': False, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 6, 22, 24, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release B', 'time:timestamp': datetime.datetime(2014, 10, 9, 4, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 20 {'attributes': {'concept:name': 'U'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 29, 20, 38, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'L', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release B', 'time:timestamp': datetime.datetime(2014, 5, 1, 19, 10, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 21 {'attributes': {'concept:name': 'V'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 28, 20, 44, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2015, 1, 19, 8, 55, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 22 {'attributes': {'concept:name': 'W'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 11, 16, 52, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'M', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 15, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 23 {'attributes': {'concept:name': 'X'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 4, 3, 41, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2015, 5, 9, 10, 52, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 24 {'attributes': {'concept:name': 'Y'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2015, 2, 25, 10, 6, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Liquid', 'time:timestamp': datetime.datetime(2015, 2, 25, 11, 0, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 25 {'attributes': {'concept:name': 'Z'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 3, 8, 49, 53, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 7, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 26 {'attributes': {'concept:name': 'AA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 3, 9, 6, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Antibiotics', 'time:timestamp': datetime.datetime(2014, 12, 3, 14, 28, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 27 {'attributes': {'concept:name': 'BA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 7, 17, 36, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 8, 1, 8, 58, 21, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 28 {'attributes': {'concept:name': 'CA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 23, 19, 11, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'Leucocytes': 2.6, 'org:group': 'B', 'lifecycle:transition': 'complete', 'concept:name': 'Leucocytes', 'time:timestamp': datetime.datetime(2013, 12, 23, 19, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 29 {'attributes': {'concept:name': 'DA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 16, 21, 57, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 2, 22, 13, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 30 {'attributes': {'concept:name': 'EA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 6, 8, 12, 28, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 11, 20, 10, 58, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 31 {'attributes': {'concept:name': 'FA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 12, 16, 30, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Antibiotics', 'time:timestamp': datetime.datetime(2014, 5, 12, 22, 17, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 32 {'attributes': {'concept:name': 'GA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 3, 8, 37, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 7, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 33 {'attributes': {'concept:name': 'HA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2013, 11, 16, 11, 38, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'N', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 22, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 34 {'attributes': {'concept:name': 'IA'}, 'events': [{'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Liquid', 'time:timestamp': datetime.datetime(2014, 7, 11, 9, 32, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Age': 75}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Antibiotics', 'time:timestamp': datetime.datetime(2014, 7, 11, 10, 2, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 35 {'attributes': {'concept:name': 'JA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 65, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 24, 10, 19, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'H', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 7, 3, 22, 59, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 36 {'attributes': {'concept:name': 'KA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 26, 7, 50, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'O', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 31, 12, 9, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 37 {'attributes': {'concept:name': 'LA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 20, 12, 11, 27, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'B', 'lifecycle:transition': 'complete', 'concept:name': 'CRP', 'time:timestamp': datetime.datetime(2014, 11, 20, 12, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 38 {'attributes': {'concept:name': 'MA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 7, 16, 15, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'P', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 10, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 39 {'attributes': {'concept:name': 'NA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 10, 1, 45, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': True, 'Oligurie': True, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': True, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 11, 22, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 40 {'attributes': {'concept:name': 'OA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 20, 22, 42, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'B', 'LacticAcid': 4.9, 'lifecycle:transition': 'complete', 'concept:name': 'LacticAcid', 'time:timestamp': datetime.datetime(2013, 12, 21, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 41 {'attributes': {'concept:name': 'PA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 3, 12, 1, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'B', 'LacticAcid': 3.2, 'lifecycle:transition': 'complete', 'concept:name': 'LacticAcid', 'time:timestamp': datetime.datetime(2014, 11, 3, 12, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 42 {'attributes': {'concept:name': 'QA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 23, 19, 53, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'Q', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release D', 'time:timestamp': datetime.datetime(2014, 12, 30, 10, 10, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 43 {'attributes': {'concept:name': 'RA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 7, 14, 52, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 10, 7, 15, 38, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 44 {'attributes': {'concept:name': 'SA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'L', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 17, 15, 17, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'R', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 4, 11, 18, 34, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# ...
# 1035 {'attributes': {'concept:name': 'XMA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 40, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 5, 18, 0, 13, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 5, 18, 0, 26, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1036 {'attributes': {'concept:name': 'YMA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 1, 22, 26, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'OE', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 9, 26, 22, 9, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1037 {'attributes': {'concept:name': 'ZMA'}, 'events': [{'org:group': 'A', 'concept:name': 'IV Liquid', 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Age': 70, 'time:timestamp': datetime.datetime(2014, 10, 19, 10, 45, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release B', 'time:timestamp': datetime.datetime(2014, 12, 3, 15, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1038 {'attributes': {'concept:name': 'ANA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 5, 16, 17, 11, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'ZB', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 17, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1039 {'attributes': {'concept:name': 'BNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 30, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 6, 15, 22, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'Z', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 9, 12, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1040 {'attributes': {'concept:name': 'CNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 65, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 19, 8, 14, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'BA', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': '?', 'lifecycle:transition': 'complete', 'concept:name': 'Return ER', 'time:timestamp': datetime.datetime(2014, 10, 6, 10, 36, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1041 {'attributes': {'concept:name': 'DNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 10, 4, 25, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Antibiotics', 'time:timestamp': datetime.datetime(2014, 11, 10, 7, 4, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1042 {'attributes': {'concept:name': 'ENA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 20, 9, 25, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True}, '..', {'Leucocytes': 17.6, 'org:group': 'B', 'lifecycle:transition': 'complete', 'concept:name': 'Leucocytes', 'time:timestamp': datetime.datetime(2014, 11, 20, 9, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1043 {'attributes': {'concept:name': 'FNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 9, 8, 20, 49, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'PE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'IV Liquid', 'time:timestamp': datetime.datetime(2014, 9, 9, 22, 5, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1044 {'attributes': {'concept:name': 'GNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 7, 31, 0, 25, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 6, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1045 {'attributes': {'concept:name': 'HNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 8, 1, 10, 26, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 13, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))}]}
# 1046 {'attributes': {'concept:name': 'INA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 25, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 3, 9, 43, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 11, 3, 10, 45, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1047 {'attributes': {'concept:name': 'JNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 40, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 12, 17, 40, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 11, 12, 17, 47, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1048 {'attributes': {'concept:name': 'KNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 35, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 11, 23, 28, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'QE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 16, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}
# 1049 {'attributes': {'concept:name': 'LNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}

# %%
conf_check_res.get_metric(metric="num_fulfillments")
# Out:
# [[<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
# ...
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  [<TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>,
#   <TraceState.VIOLATED: 'Violated'>],
#  ...]

# %% [markdown]
# Once the log and the DECLARE model are loaded, the `conformance_checking()` function will perform the model checking. The input boolean parameter `consider_vacuity=true` means that vacuously satisfied traces are considered as satisfied, violated otherwise. This function returns a Python dictionary containing the results indexed by trace in the log. Each key is a tuple containing the trace id and its name (that can be retrieved with `get_trace_keys()`). The value is a Python dictionary with keys the names of the constraints (that can be retrieved with `model_constraints()`) and values a `CheckerResult` object containing the number of pendings, activations, violations, fulfilments and the truth value of the trace for that constraint.
#
# ```
# model_check_res = {trace_1: {constr_1: CheckerResult object, constr_2: CheckerResult object, ...},
#                    trace_2: {constr_1: CheckerResult object, ... },
#                     ...
#                   }
# ```
# The `CheckerResult` objects can be accessed by the attributes `num_pendings`, `num_activations`, `num_fulfillments`, `num_violations` and `state`.

# %%
model_check_res = d4py.conformance_checking(consider_vacuity=False)

# %% [markdown]
# Let's inspect the results for the trace `(1, 'B')` and the constraint
# `Chain Response[LacticAcid, Leucocytes] |A.LacticAcid <= 0.8 |T.Leucocytes >= 13.8 |0,2778,m`

# %%
constr_id = 11
trace_id = (1, 'B')
print(f"Constraint to check: {model_constraints[constr_id]}")
print(f"Number of pendings: {model_check_res[trace_id][model_constraints[constr_id]].num_pendings}")
print(f"Number of activations: {model_check_res[trace_id][model_constraints[constr_id]].num_activations}")
print(f"Number of fulfilments: {model_check_res[trace_id][model_constraints[constr_id]].num_fulfillments}")
print(f"Number of violation: {model_check_res[trace_id][model_constraints[constr_id]].num_violations}")
print(f"Truth value: {model_check_res[trace_id][model_constraints[constr_id]].state}")

# %% [markdown]
# The checker results can be printed with the `print_conformance_results` function.
