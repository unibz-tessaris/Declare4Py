# %% [markdown]
# # Encodings
#
# ## Log Binary Encoding
# One-hot encoding (i.e. binary encoding) is also provided by this class, which can be useful for Machine Learning tasks or statistical analysis. The function `log_encoding` takes as input the `dimension` and is optional. The default value for this parameter is defaulted to `act`, which are the activity names. It can also be set to `payload`. This function sets the attribute `binary_encoded_log` and returns it, the attribute is a __Pandas__ __DataFrame__.

# %%
import sys
import os
import pathlib

SCRIPT_DIR = pathlib.Path("..", "src").resolve()
sys.path.append(os.path.dirname(SCRIPT_DIR))


from src.declare4py.encodings.PreviousStateTransformer import PreviousStateTransformer
from src.declare4py.encodings.LastStateTransformer import LastStateTransformer
from src.declare4py.encodings.AggregateTransformer import AggregateTransformer
from src.declare4py.encodings.IndexBasedTransformer import IndexBasedTransformer
from src.declare4py.encodings.StaticTransformer import StaticTransformer
import pm4py
import os
from sklearn.pipeline import Pipeline
import pandas as pd

# %%
data = pm4py.read_xes("SepsisCasesEventLog.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]

# %%
df = pm4py.convert_to_dataframe(data)
df.head()
# Out:
#   InfectionSuspected org:group DiagnosticBlood DisfuncOrg SIRSCritTachypnea  \
# 0               True         A            True       True              True
# 1                NaN         B             NaN        NaN               NaN
# 2                NaN         B             NaN        NaN               NaN
# 3                NaN         B             NaN        NaN               NaN
# 4                NaN         C             NaN        NaN               NaN
#
#   Hypotensie SIRSCritHeartRate Infusion DiagnosticArtAstrup     concept:name  \
# 0       True              True     True                True  ER Registration
# 1        NaN               NaN      NaN                 NaN       Leucocytes
# 2        NaN               NaN      NaN                 NaN              CRP
# 3        NaN               NaN      NaN                 NaN       LacticAcid
# 4        NaN               NaN      NaN                 NaN        ER Triage
#
#    ...  DiagnosticLacticAcid lifecycle:transition Diagnose Hypoxie  \
# 0  ...                  True             complete        A   False
# 1  ...                   NaN             complete      NaN     NaN
# 2  ...                   NaN             complete      NaN     NaN
# 3  ...                   NaN             complete      NaN     NaN
# 4  ...                   NaN             complete      NaN     NaN
#
#   DiagnosticUrinarySediment DiagnosticECG case:concept:name Leucocytes   CRP  \
# 0                      True          True                 A        NaN   NaN
# 1                       NaN           NaN                 A        9.6   NaN
# 2                       NaN           NaN                 A        NaN  21.0
# 3                       NaN           NaN                 A        NaN   NaN
# 4                       NaN           NaN                 A        NaN   NaN
#
#   LacticAcid
# 0        NaN
# 1        NaN
# 2        NaN
# 3        2.2
# 4        NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Boolean encoding
#
# Select the categorical columns, leave the numeric columns empty, set boolean to true

# %%
encoder = AggregateTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=[], boolean=True)
#enc_df = encoder.fit_transform(df)
#enc_df.head()

# %% [markdown]
# ## Frequency-based encoding
#
# Select the categorical columns, leave the numeric columns empty, set boolean to false

# %%
encoder = AggregateTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=[], boolean=False)
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                    concept:name_Admission IC  concept:name_Admission NC  \
# case:concept:name
# A                                          0                          1
# AA                                         0                          0
# AAA                                        0                          1
# AB                                         0                          0
# ABA                                        0                          1
#
#                    concept:name_CRP  concept:name_ER Registration  \
# case:concept:name
# A                                 7                             1
# AA                                1                             1
# AAA                               1                             1
# AB                                1                             1
# ABA                               4                             1
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              1                       1
# AA                                             1                       1
# AAA                                            1                       1
# AB                                             1                       1
# ABA                                            1                       1
#
#                    concept:name_IV Antibiotics  concept:name_IV Liquid  \
# case:concept:name
# A                                            1                       1
# AA                                           1                       1
# AAA                                          1                       1
# AB                                           1                       1
# ABA                                          1                       1
#
#                    concept:name_LacticAcid  concept:name_Leucocytes  ...  \
# case:concept:name                                                    ...
# A                                        1                        7  ...
# AA                                       1                        1  ...
# AAA                                      1                        1  ...
# AB                                       1                        1  ...
# ABA                                      1                        5  ...
#
#                    org:group_P  org:group_Q  org:group_R  org:group_S  \
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
#                    org:group_T  org:group_U  org:group_V  org:group_W  \
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
#                    org:group_X  org:group_Y
# case:concept:name
# A                            0            0
# AA                           0            0
# AAA                          0            0
# AB                           0            0
# ABA                          0            0
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Aggregated encoding
#
# Select the categorical and numerical columns, set boolean to false. Categorical columns are converted into frequency encoding. Numerical columns are aggregated according to 'mean', 'max', 'min', 'sum', 'std' (da sistemare

# %%
encoder = AggregateTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=['CRP'], boolean=False)
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                    concept:name_Admission IC  concept:name_Admission NC  \
# case:concept:name
# A                                          0                          1
# AA                                         0                          0
# AAA                                        0                          1
# AB                                         0                          0
# ABA                                        0                          1
#
#                    concept:name_CRP  concept:name_ER Registration  \
# case:concept:name
# A                                 7                             1
# AA                                1                             1
# AAA                               1                             1
# AB                                1                             1
# ABA                               4                             1
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              1                       1
# AA                                             1                       1
# AAA                                            1                       1
# AB                                             1                       1
# ABA                                            1                       1
#
#                    concept:name_IV Antibiotics  concept:name_IV Liquid  \
# case:concept:name
# A                                            1                       1
# AA                                           1                       1
# AAA                                          1                       1
# AB                                           1                       1
# ABA                                          1                       1
#
#                    concept:name_LacticAcid  concept:name_Leucocytes  ...  \
# case:concept:name                                                    ...
# A                                        1                        7  ...
# AA                                       1                        1  ...
# AAA                                      1                        1  ...
# AB                                       1                        1  ...
# ABA                                      1                        5  ...
#
#                    org:group_U  org:group_V  org:group_W  org:group_X  \
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
#                    org:group_Y    CRP_mean  CRP_max  CRP_min  CRP_sum  \
# case:concept:name
# A                            0   30.857143    109.0      6.0    216.0
# AA                           0   23.000000     23.0     23.0     23.0
# AAA                          0   68.000000     68.0     68.0     68.0
# AB                           0   48.000000     48.0     48.0     48.0
# ABA                          0  105.000000    140.0     78.0    420.0
#
#                      CRP_std
# case:concept:name
# A                  37.168215
# AA                  0.000000
# AAA                 0.000000
# AB                  0.000000
# ABA                28.154337
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Indexed Encodings

# %% [markdown]
# ### Simple Index encoding
#
# se max_events = n allora prendi i primi n, se None allora piglia tutto, create_dummies = one hot encoding

# %%
encoder = IndexBasedTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name'], num_cols=[], create_dummies=False)
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                   case:concept:name   concept:name_0 concept:name_1  \
# case:concept:name
# A                                 A  ER Registration     Leucocytes
# AA                               AA  ER Registration      ER Triage
# AAA                             AAA  ER Registration      ER Triage
# AB                               AB  ER Registration      ER Triage
# ABA                             ABA  ER Registration      ER Triage
#
#                      concept:name_2 concept:name_3 concept:name_4  \
# case:concept:name
# A                               CRP     LacticAcid      ER Triage
# AA                 ER Sepsis Triage     Leucocytes     LacticAcid
# AAA                ER Sepsis Triage      IV Liquid     Leucocytes
# AB                 ER Sepsis Triage            CRP     LacticAcid
# ABA                ER Sepsis Triage      IV Liquid     LacticAcid
#
#                      concept:name_5 concept:name_6  concept:name_7  \
# case:concept:name
# A                  ER Sepsis Triage      IV Liquid  IV Antibiotics
# AA                              CRP      IV Liquid  IV Antibiotics
# AAA                             CRP     LacticAcid  IV Antibiotics
# AB                       Leucocytes      IV Liquid  IV Antibiotics
# ABA                      Leucocytes            CRP  IV Antibiotics
#
#                   concept:name_8  ... concept:name_175 concept:name_176  \
# case:concept:name                 ...
# A                   Admission NC  ...                0                0
# AA                             0  ...                0                0
# AAA                 Admission NC  ...                0                0
# AB                             0  ...                0                0
# ABA                 Admission NC  ...                0                0
#
#                   concept:name_177 concept:name_178 concept:name_179  \
# case:concept:name
# A                                0                0                0
# AA                               0                0                0
# AAA                              0                0                0
# AB                               0                0                0
# ABA                              0                0                0
#
#                   concept:name_180 concept:name_181 concept:name_182  \
# case:concept:name
# A                                0                0                0
# AA                               0                0                0
# AAA                              0                0                0
# AB                               0                0                0
# ABA                              0                0                0
#
#                   concept:name_183 concept:name_184
# case:concept:name
# A                                0                0
# AA                               0                0
# AAA                              0                0
# AB                               0                0
# ABA                              0                0
#
# [5 rows x 186 columns]

# %% [markdown]
# ### Complex Index encoding
#
# se max_events = n allora prendi i primi n, se None allora piglia tutto, aggiungi colonne a cat_cols o num_cols, create_dummies = one hot encoding

# %%
encoder = IndexBasedTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=[], )
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                    concept:name_0_CRP  concept:name_0_ER Registration  \
# case:concept:name
# A                                   0                               1
# AA                                  0                               1
# AAA                                 0                               1
# AB                                  0                               1
# ABA                                 0                               1
#
#                    concept:name_0_ER Sepsis Triage  concept:name_0_ER Triage  \
# case:concept:name
# A                                                0                         0
# AA                                               0                         0
# AAA                                              0                         0
# AB                                               0                         0
# ABA                                              0                         0
#
#                    concept:name_0_IV Liquid  concept:name_0_Leucocytes  \
# case:concept:name
# A                                         0                          0
# AA                                        0                          0
# AAA                                       0                          0
# AB                                        0                          0
# ABA                                       0                          0
#
#                    concept:name_1_CRP  concept:name_1_ER Registration  \
# case:concept:name
# A                                   0                               0
# AA                                  0                               0
# AAA                                 0                               0
# AB                                  0                               0
# ABA                                 0                               0
#
#                    concept:name_1_ER Sepsis Triage  concept:name_1_ER Triage  \
# case:concept:name
# A                                                0                         0
# AA                                               0                         1
# AAA                                              0                         1
# AB                                               0                         1
# ABA                                              0                         1
#
#                    ...  org:group_175_B  org:group_176_B  org:group_177_B  \
# case:concept:name  ...
# A                  ...                0                0                0
# AA                 ...                0                0                0
# AAA                ...                0                0                0
# AB                 ...                0                0                0
# ABA                ...                0                0                0
#
#                    org:group_178_B  org:group_179_B  org:group_180_B  \
# case:concept:name
# A                                0                0                0
# AA                               0                0                0
# AAA                              0                0                0
# AB                               0                0                0
# ABA                              0                0                0
#
#                    org:group_181_B  org:group_182_B  org:group_183_B  \
# case:concept:name
# A                                0                0                0
# AA                               0                0                0
# AAA                              0                0                0
# AB                               0                0                0
# ABA                              0                0                0
#
#                    org:group_184_E
# case:concept:name
# A                                0
# AA                               0
# AAA                              0
# AB                               0
# ABA                              0
#
# [5 rows x 1215 columns]

# %% [markdown]
# ## Static Encodings
#
# ### First state
# the information (CF + payload) of the first event

# %%
encoder = StaticTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=['CRP'])
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                     CRP  concept:name_CRP  concept:name_ER Registration  \
# case:concept:name
# A                  21.0                 0                             1
# AA                 23.0                 0                             1
# AAA                68.0                 0                             1
# AB                 48.0                 0                             1
# ABA                78.0                 0                             1
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              0                       0
# AA                                             0                       0
# AAA                                            0                       0
# AB                                             0                       0
# ABA                                            0                       0
#
#                    concept:name_IV Liquid  concept:name_Leucocytes  \
# case:concept:name
# A                                       0                        0
# AA                                      0                        0
# AAA                                     0                        0
# AB                                      0                        0
# ABA                                     0                        0
#
#                    org:group_A  org:group_B  org:group_C  org:group_L
# case:concept:name
# A                            1            0            0            0
# AA                           1            0            0            0
# AAA                          1            0            0            0
# AB                           1            0            0            0
# ABA                          1            0            0            0

# %% [markdown]
# ### Second to last state
# the information (CF + payload) of the second to last event

# %%
encoder = PreviousStateTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=['CRP'])
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                    CRP  concept:name_Admission NC  concept:name_CRP  \
# case:concept:name
# A                  0.0                          0                 0
# AA                 0.0                          0                 0
# AAA                0.0                          0                 0
# AB                 0.0                          0                 0
# ABA                0.0                          0                 0
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              0                       0
# AA                                             0                       0
# AAA                                            0                       0
# AB                                             0                       0
# ABA                                            0                       0
#
#                    concept:name_IV Antibiotics  concept:name_IV Liquid  \
# case:concept:name
# A                                            0                       0
# AA                                           0                       1
# AAA                                          0                       0
# AB                                           0                       1
# ABA                                          0                       0
#
#                    concept:name_LacticAcid  concept:name_Leucocytes  \
# case:concept:name
# A                                        0                        1
# AA                                       0                        0
# AAA                                      0                        0
# AB                                       0                        0
# ABA                                      0                        1
#
#                    concept:name_Release A  ...  org:group_M  org:group_N  \
# case:concept:name                          ...
# A                                       0  ...            0            0
# AA                                      0  ...            0            0
# AAA                                     1  ...            0            0
# AB                                      0  ...            0            0
# ABA                                     0  ...            0            0
#
#                    org:group_O  org:group_P  org:group_Q  org:group_R  \
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
#                    org:group_S  org:group_T  org:group_U  org:group_V
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Last state
# the information (CF + payload) of the last event

# %%
encoder = LastStateTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name', 'org:group'], num_cols=['CRP'])
enc_df = encoder.fit_transform(df)
enc_df.head()
# Out:
#                      CRP  concept:name_Admission NC  concept:name_CRP  \
# case:concept:name
# A                    6.0                          0                 0
# AA                  23.0                          0                 0
# AAA                 68.0                          0                 0
# AB                  48.0                          0                 0
# ABA                140.0                          0                 0
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              0                       0
# AA                                             0                       0
# AAA                                            0                       0
# AB                                             0                       0
# ABA                                            0                       0
#
#                    concept:name_IV Antibiotics  concept:name_IV Liquid  \
# case:concept:name
# A                                            0                       0
# AA                                           1                       0
# AAA                                          0                       0
# AB                                           1                       0
# ABA                                          0                       0
#
#                    concept:name_LacticAcid  concept:name_Leucocytes  \
# case:concept:name
# A                                        0                        0
# AA                                       0                        0
# AAA                                      0                        0
# AB                                       0                        0
# ABA                                      0                        0
#
#                    concept:name_Release A  ...  org:group_B  org:group_C  \
# case:concept:name                          ...
# A                                       1  ...            0            0
# AA                                      0  ...            0            0
# AAA                                     0  ...            0            0
# AB                                      0  ...            0            0
# ABA                                     1  ...            0            0
#
#                    org:group_D  org:group_E  org:group_F  org:group_G  \
# case:concept:name
# A                            0            1            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            1            0            0
#
#                    org:group_I  org:group_L  org:group_R  org:group_V
# case:concept:name
# A                            0            0            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            0            0            0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Index latest-payload
#
# combination of a index-based encoding with a static one (the last state)

# %%
last_state_encoder = LastStateTransformer(case_id_col = 'case:concept:name', cat_cols = ['org:group'], num_cols=[])
latest_df = last_state_encoder.fit_transform(df)

simple_index_encoder = IndexBasedTransformer(case_id_col = 'case:concept:name', cat_cols = ['concept:name'], num_cols=[], create_dummies=True)
simple_df = simple_index_encoder.fit_transform(df)

index_latest_payload_df = pd.concat([latest_df, simple_df], axis=1)
index_latest_payload_df.head()
# Out:
#                    org:group_?  org:group_A  org:group_B  org:group_C  \
# case:concept:name
# A                            0            0            0            0
# AA                           0            1            0            0
# AAA                          1            0            0            0
# AB                           0            1            0            0
# ABA                          0            0            0            0
#
#                    org:group_D  org:group_E  org:group_F  org:group_G  \
# case:concept:name
# A                            0            1            0            0
# AA                           0            0            0            0
# AAA                          0            0            0            0
# AB                           0            0            0            0
# ABA                          0            1            0            0
#
#                    org:group_I  org:group_L  ...  concept:name_175_Leucocytes  \
# case:concept:name                            ...
# A                            0            0  ...                            0
# AA                           0            0  ...                            0
# AAA                          0            0  ...                            0
# AB                           0            0  ...                            0
# ABA                          0            0  ...                            0
#
#                    concept:name_176_CRP  concept:name_177_CRP  \
# case:concept:name
# A                                     0                     0
# AA                                    0                     0
# AAA                                   0                     0
# AB                                    0                     0
# ABA                                   0                     0
#
#                    concept:name_178_Leucocytes  concept:name_179_Leucocytes  \
# case:concept:name
# A                                            0                            0
# AA                                           0                            0
# AAA                                          0                            0
# AB                                           0                            0
# ABA                                          0                            0
#
#                    concept:name_180_CRP  concept:name_181_Leucocytes  \
# case:concept:name
# A                                     0                            0
# AA                                    0                            0
# AAA                                   0                            0
# AB                                    0                            0
# ABA                                   0                            0
#
#                    concept:name_182_CRP  concept:name_183_Leucocytes  \
# case:concept:name
# A                                     0                            0
# AA                                    0                            0
# AAA                                   0                            0
# AB                                    0                            0
# ABA                                   0                            0
#
#                    concept:name_184_Release C
# case:concept:name
# A                                           0
# AA                                          0
# AAA                                         0
# AB                                          0
# ABA                                         0
#
# [5 rows x 668 columns]

# %% [markdown]
# ## The Declare encoding

# %% [markdown]
# ## A ML Pipeline with Declare4Py

# %%
pipe = Pipeline(
    steps=[
        ("StaticTransformer", StaticTransformer(case_id_col = 'case:concept:name',
                        cat_cols = ['concept:name', 'org:group'], 
                        num_cols = ['CRP' ]
                        ))
    ]
)
Static_df = pipe.fit_transform(df)
Static_df.head()
# Out:
#                     CRP  concept:name_CRP  concept:name_ER Registration  \
# case:concept:name
# A                  21.0                 0                             1
# AA                 23.0                 0                             1
# AAA                68.0                 0                             1
# AB                 48.0                 0                             1
# ABA                78.0                 0                             1
#
#                    concept:name_ER Sepsis Triage  concept:name_ER Triage  \
# case:concept:name
# A                                              0                       0
# AA                                             0                       0
# AAA                                            0                       0
# AB                                             0                       0
# ABA                                            0                       0
#
#                    concept:name_IV Liquid  concept:name_Leucocytes  \
# case:concept:name
# A                                       0                        0
# AA                                      0                        0
# AAA                                     0                        0
# AB                                      0                        0
# ABA                                     0                        0
#
#                    org:group_A  org:group_B  org:group_C  org:group_L
# case:concept:name
# A                            1            0            0            0
# AA                           1            0            0            0
# AAA                          1            0            0            0
# AB                           1            0            0            0
# ABA                          1            0            0            0
