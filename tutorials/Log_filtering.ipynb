# %% [markdown]
# # Filtering a Log
#
# The class `ProcessMiningTasks.LogFiltering.BasicFilters.BasicFilters` provides several functions to filter a log according to some input requirements. The `BasicFilters` class provides the following filtering functions:
# 1. `filter_time_range_contained` that ...
# 2. `filter_case_performance` that filters the log by a range of minimum performance and maximum performance, which is the duration of a case.
# 3. `filter_start_activities` that filters all the activities that start with the specified set of start activities.
# 4. `filter_end_activities` that filters all the activities that end with the specified set of end activities.
# 5. `filter_variants_top_k` retains the top-k variants of the log.
# 6. `filter_variants` filters a log by a specified set of variants.
# 7. `filter_event_attribute_values` filters a log by the values of some event attribute.
#
# We first import such a class and the input `xes` log.

# %%
import sys
import os
import pathlib

SCRIPT_DIR = pathlib.Path("..", "src").resolve()
sys.path.append(os.path.dirname(SCRIPT_DIR))

from src.Declare4Py.ProcessMiningTasks.LogFiltering.BasicFilters import BasicFilters
from src.Declare4Py.D4PyEventLog import D4PyEventLog

log_path = os.path.join("..", "tests", "Sepsis Cases.xes.gz")
event_log = D4PyEventLog()
event_log.parse_xes_log(log_path)
# Out:
# parsing log, completed traces ::   0%|          | 0/1050 [00:00<?, ?it/s]

# %% [markdown]
# Then, the `BasicFilters` class is built from the `event_log` object.

# %%
log_filters = BasicFilters(event_log)

# %% [markdown]
# ## `filter_time_range_contained`
#
# The function `filter_time_range_contained` filters a log on a time interval. It takes as input:
# - `start_date` as a string of type `2013-01-01 00:00:00`;
# - `end_date` a string of type `2013-01-01 00:00:00`;
# - `mode` is modality of filtering (takes as input the values `events`, `traces_contained`, `traces_intersecting`). `events`: any event that fits the time frame is retained; `traces_contained`: any trace completely contained in the timeframe is retained; `traces_intersecting`: any trace intersecting with the time-frame is retained.

# %%
filtered_log = log_filters.filter_time_range_contained("2013-01-01 00:00:00", "2015-12-31 23:59:59", mode='traces_contained')
print(f"Filtered log for time range:\n{filtered_log}")
print("--------------------------------------")

filtered_log = log_filters.filter_time_range_contained("2013-01-01 00:00:00", "2015-12-31 23:59:59", mode='traces_constrained')
print(f"Filtered log for time range:\n{filtered_log}")
print("--------------------------------------")

filtered_log = log_filters.filter_time_range_contained("2013-01-01 00:00:00", "2015-12-31 23:59:59", mode='events')
print(f"Filtered log for time range:\n{filtered_log}")
# Out:
# Filtered log for time range:
# [{'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'A'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'A'}]}, '....', {'attributes': {'concept:name': 'LNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'LNA'}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LNA'}]}]
# --------------------------------------
# Filtered log for time range:
# [{'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'A'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'A'}]}, '....', {'attributes': {'concept:name': 'LNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'LNA'}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LNA'}]}]
# --------------------------------------
# Filtered log for time range:
# [{'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}, '....', {'attributes': {'concept:name': 'LNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))}]}]

# %% [markdown]
# ## `filter_case_performance`
#
# The function `filter_case_performance` filters the log keeping the cases having a duration (the timestamp of the last event minus the timestamp of the first event) included between `min_performance` and `max_performance`. It takes as input:
# - `min_performace`: a floating point value that represents the minimum value of the range;
# - `max_performance`: a floating point value that represents the maximum value of the range.

# %%
filtered_log = log_filters.filter_case_performance(86400, 864000)
print(f"Filtered on case performance:\n{filtered_log}")
# Out:
# Filtered on case performance:
# [{'attributes': {'concept:name': 'B'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 21, 11, 4, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'B'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 26, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'B'}]}, '....', {'attributes': {'concept:name': 'KNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 35, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 11, 23, 28, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'QE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'KNA'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 16, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KNA'}]}]

# %% [markdown]
# ## `filter_start_activities`
#
# The function `filter_start_activities` filters all the activities that start with the specified set of start activities. It takes as input:
# - `activities` can be either a set or a list. It is the collection of start activities;
# - `retain` a boolean value that if True, retains the traces containing the given start activities, if false, the traces are dropped, default values is: `True`.

# %%
start_activities = ["ER Registration", "CRP"]
filtered_log = log_filters.filter_start_activities(start_activities)
print(f"First event of the filtered log with {start_activities} as start activities:\n")
for case in filtered_log:
    print(case[0])
# Out:
# First event of the filtered log with ['ER Registration', 'CRP'] as start activities:
#
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'A'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 21, 11, 4, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'B'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 9, 19, 29, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'C'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 7, 10, 11, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'D'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2015, 1, 15, 20, 14, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'E'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 7, 18, 56, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'F'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 9, 5, 14, 40, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'F', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'G'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 3, 11, 9, 50, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'H'}
# {'InfectionSuspected': True, 'org:group': 'L', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 11, 9, 9, 21, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'H', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'I'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 2, 16, 45, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'J'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 23, 21, 43, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'I', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'K'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 8, 31, 18, 47, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'J', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'L'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 10, 3, 8, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'M'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 6, 16, 10, 34, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'K', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': False, 'case:concept:name': 'N'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 30, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 11, 22, 29, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'O'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 20, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 22, 9, 39, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'P'}
# {'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2013, 12, 15, 14, 17, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'Q'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 30, 12, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'R'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 21, 12, 16, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'S'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': False, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 6, 22, 24, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'T'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 29, 20, 38, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'L', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'U'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 60, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 28, 20, 44, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'V'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 11, 16, 52, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'M', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'W'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 4, 3, 41, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'X'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2015, 2, 25, 10, 6, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'Y'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 3, 8, 49, 53, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'Z'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 3, 9, 6, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'AA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 7, 17, 36, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'BA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 23, 19, 11, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'CA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 16, 21, 57, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'DA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 6, 8, 12, 28, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'D', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'EA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 12, 16, 30, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'FA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 3, 8, 37, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'GA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2013, 11, 16, 11, 38, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'N', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'HA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 65, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 24, 10, 19, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'H', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'JA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 26, 7, 50, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'O', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'KA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 20, 12, 11, 27, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'LA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 7, 16, 15, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'P', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'MA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 10, 1, 45, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': True, 'Oligurie': True, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': True, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'NA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2013, 12, 20, 22, 42, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'OA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 3, 12, 1, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'PA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 23, 19, 53, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'Q', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'QA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 7, 14, 52, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'RA'}
# {'InfectionSuspected': True, 'org:group': 'L', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 17, 15, 17, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'R', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'SA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 8, 9, 22, 23, 4, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'TA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 3, 23, 8, 19, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'UA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 9, 19, 0, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'C', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'VA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 28, 16, 35, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'S', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'WA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 70, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 4, 12, 15, 18, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'XA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 7, 10, 12, 33, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'YA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 5, 24, 11, 32, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'ZA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 16, 9, 55, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'AB'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 35, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 3, 10, 12, 13, 21, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'BB'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 2, 11, 12, 36, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'CB'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 6, 4, 11, 56, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'DB'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 17, 10, 2, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'EB'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 5, 21, 17, 2, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'FB'}
# ...
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 3, 31, 11, 30, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'SMA'}
# {'InfectionSuspected': True, 'org:group': 'L', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 40, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 1, 15, 9, 52, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'TMA'}
# {'CRP': 82.0, 'org:group': 'B', 'concept:name': 'CRP', 'lifecycle:transition': 'complete', 'Diagnose': 'E', 'Age': 25, 'time:timestamp': datetime.datetime(2014, 6, 8, 12, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UMA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 25, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 6, 20, 18, 19, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'VMA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 20, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 17, 15, 29, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'WMA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 40, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 5, 18, 0, 13, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'XMA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 1, 22, 26, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'OE', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'YMA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 5, 16, 17, 11, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'ZB', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'ANA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 30, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': True, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 6, 15, 22, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'Z', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'BNA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 65, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 9, 19, 8, 14, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Diagnose': 'BA', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'CNA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 10, 4, 25, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'DNA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 11, 20, 9, 25, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': True, 'case:concept:name': 'ENA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 80, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 9, 8, 20, 49, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'PE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'FNA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 55, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 7, 31, 0, 25, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'GNA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 75, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 8, 1, 10, 26, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'G', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'HNA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 25, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 3, 9, 43, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'INA'}
# {'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 40, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 11, 12, 17, 40, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'JNA'}
# {'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 35, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 11, 23, 28, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'QE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'KNA'}
# {'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'LNA'}

# %% [markdown]
# ##  `filter_end_activities`
#
# The function `filter_end_activities` filters all the activities that end with the specified set of end activities. It takes as input:
# - `activities` can be either a set or a list. It is the collection of the end activities;
# - `retain` a boolean value that if True, retains the traces containing the given start activities, if false, the traces are dropped, default values is: `True`.

# %%
end_activities = ["Release A", "Release C"]
filtered_log = log_filters.filter_end_activities(end_activities)
print(f"Last event of the filtered log with {end_activities} as end activities:\n")
for case in filtered_log:
    print(case[-1])
# Out:
# Last event of the filtered log with ['Release A', 'Release C'] as end activities:
#
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'A'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 26, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'B'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 15, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'C'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 9, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'F'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 12, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'G'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 16, 13, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'I'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 6, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'J'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 21, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'N'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 15, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'W'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 7, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'Z'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 2, 22, 13, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'DA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 7, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 22, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 31, 12, 9, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 10, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'MA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 11, 22, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'NA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 12, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 28, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'UA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 15, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'VA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 18, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 9, 11, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 22, 11, 39, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 28, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'IB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 19, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 13, 10, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'OB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 25, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 13, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'YB'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 16, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'EC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 13, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'FC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 31, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 22, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 1, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 19, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VC'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 5, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 7, 12, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 14, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 1, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 8, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ND'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 1, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'SD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 8, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 25, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'XD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 12, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZD'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 21, 8, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'CE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 23, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'EE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 8, 10, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 13, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 31, 10, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'IE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 16, 11, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'SE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 30, 10, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 15, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 29, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YE'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 6, 15, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'EF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 31, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 18, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'IF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 5, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 27, 12, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 10, 21, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'PF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 12, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'UF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 30, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'VF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 13, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'XF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 21, 9, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 9, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZF'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 9, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 29, 8, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 22, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 13, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'FG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 13, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'IG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 23, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'JG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 24, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 16, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'OG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 17, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'TG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 29, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'WG'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 24, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'AH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 6, 11, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 24, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 17, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'EH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 7, 14, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 3, 13, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 28, 11, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 9, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 28, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'XH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 25, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'YH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 5, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZH'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 10, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 1, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 20, 15, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 6, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'PI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 25, 12, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 18, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'SI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2015, 2, 27, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'TI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 20, 12, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'UI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 8, 15, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZI'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 9, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'AJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 28, 12, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 27, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'EJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 17, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 31, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'IJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 16, 16, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 31, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 9, 9, 44, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'MJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 14, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'OJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 20, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 28, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 21, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 22, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZJ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 16, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'FK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 4, 25, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 23, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 24, 9, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 19, 13, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 24, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 3, 7, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 13, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 13, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 12, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 2, 15, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ZK'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 8, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'BL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 11, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'DL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 4, 10, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'EL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 29, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'IL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 26, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'JL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 20, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'LL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 6, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'RL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 22, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 2, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'VL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 23, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WL'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 30, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 23, 10, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'FM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2015, 2, 18, 9, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'GM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 2, 8, 13, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 1, 12, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'IM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 29, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 10, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'MM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 10, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 17, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 11, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'VM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 23, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZM'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 22, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 29, 5, 10, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'JN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 18, 22, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 13, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 17, 11, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ON'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 24, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 14, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'TN'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 21, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 11, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'FO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 1, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'GO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 13, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 9, 10, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'MO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 17, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 27, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'OO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 4, 11, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'PO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 9, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 11, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ZO'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 14, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'BP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 4, 28, 11, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'CP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 18, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 22, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'GP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 25, 15, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 15, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 2, 10, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 19, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 9, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 18, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 5, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 1, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'XP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 16, 13, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ZP'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 12, 14, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'AQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 30, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'BQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 28, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 29, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 31, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 28, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'OQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 28, 19, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'PQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 11, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'QQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 18, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'YQ'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 25, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 21, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 10, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'LR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 2, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'MR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2015, 2, 6, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'PR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 11, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'SR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 4, 11, 9, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 9, 5, 11, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 1, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 30, 15, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ZR'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 8, 15, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'BS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 6, 10, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'DS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 2, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'IS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 2, 11, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 20, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'PS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 11, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'QS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 6, 8, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 5, 1, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 6, 14, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'US'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 28, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VS'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 6, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'CT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 2, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'DT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 29, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ET'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 26, 13, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'FT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 7, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 25, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 29, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 20, 10, 0, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'LT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 16, 19, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 30, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'PT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 6, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UT'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 15, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'VT'}
# ...
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 7, 15, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'BHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 10, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'EHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 12, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 2, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 11, 14, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'IHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 7, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 20, 13, 46, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 13, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'LHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 18, 11, 36, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 10, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'OHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 13, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'QHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 6, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 4, 16, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'SHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 14, 11, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'THA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 3, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 28, 10, 2, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'YHA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 3, 23, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'FIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 29, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'IIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 23, 13, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 25, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'OIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 5, 15, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'RIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 7, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 3, 9, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 13, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'VIA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 1, 10, 12, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'CJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 15, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'EJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 13, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'FJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 13, 13, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'HJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 9, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 29, 15, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 9, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release C', 'time:timestamp': datetime.datetime(2014, 7, 5, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 7, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'XJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 30, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 12, 12, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ZJA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 12, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'CKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 12, 12, 14, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'EKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 19, 9, 19, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'FKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 27, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 15, 10, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'MKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 10, 12, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'NKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 25, 11, 27, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'OKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 25, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'RKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 15, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'TKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 24, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 30, 14, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'YKA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 5, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ALA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 7, 1, 13, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ELA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 10, 10, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GLA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 5, 14, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HLA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 19, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'JLA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 28, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'KLA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 19, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'SLA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 20, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'ULA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 1, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'AMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2015, 2, 27, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'GMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 2, 11, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'JMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 13, 15, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'LMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 3, 26, 19, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'NMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2013, 11, 25, 11, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'PMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 31, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'QMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 4, 6, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'SMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 1, 17, 17, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'TMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 6, 12, 14, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'UMA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 5, 17, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'ANA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 9, 9, 12, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'BNA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 6, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'GNA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 8, 13, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'HNA'}
# {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 16, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KNA'}

# %% [markdown]
# ## `filter_variants_top_k`
#
# The function `filter_variants_top_k` retains the top-k variants of the log. It takes as input:
# - `k` number of variants that should be kept.

# %%
k = 2
filtered_variants = log_filters.filter_variants_top_k(k)
print(f"Filtered log on cases following one of the {k} most frequent variants:\n{filtered_variants}")
# Out:
# Filtered log on cases following one of the 2 most frequent variants:
# [{'attributes': {'concept:name': 'M'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 90, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 10, 10, 3, 8, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'M'}, '..', {'org:group': 'A', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 10, 10, 3, 10, 54, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'M'}]}, '....', {'attributes': {'concept:name': 'WMA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'A', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 20, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': False, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 4, 17, 15, 29, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'WMA'}, '..', {'CRP': 40.0, 'org:group': 'B', 'lifecycle:transition': 'complete', 'concept:name': 'CRP', 'time:timestamp': datetime.datetime(2014, 4, 17, 16, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'case:concept:name': 'WMA'}]}]

# %% [markdown]
# ## `filter_variants`
#
# The function `filter_variants` filters a log by a specified set of variants. It takes as input:
# - `variants` can be either a set or a list. It is the collection of the variants by which we want to filter;
# - `retain` a boolean value that if True, retains the traces containing the given start activities, if false, the traces are dropped, default values is: `True`.

# %%
filtered_variants = log_filters.filter_variants([("ER Registration", "Leucocytes", "CRP", "LacticAcid", "ER Triage", "ER Sepsis Triage", "IV Liquid", "IV Antibiotics", "Admission NC", "CRP,Leucocytes", "Leucocytes", "CRP", "Leucocytes", "CRP", "CRP", "Leucocytes", "Leucocytes", "CRP", "CRP", "Leucocytes", "Release A")])
print(f"Filtered variants on given collection:\n{filtered_variants}")
# Out:
# Filtered variants on given collection:
# [{'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'A'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'A'}]}]

# %% [markdown]
# ## `filter_event_attribute_values`
#
# The function `filter_event_attribute_values` filters an event log by the values of some event attribute. It takes as inputs:
# - `attribute_key` attribute to filter;
# - `values` admitted (or forbidden) values (accepted both sets and lists);
# - `level` specifies how the filter should be applied, default values is: `case`, which filters the cases where at least one occurrence happens, `event` filter the events eventually trimming the cases;
# - `retain` a boolean value that specifies if the values should be kept or removed, default values is: `True`.

# %%
# This filter keeps the cases where the attribute 'org:group' (i.e., the resource) takes 'A' or 'B' as values
filtered_log = log_filters.filter_event_attribute_values('org:group', ['A', 'B'], level="case", retain=True)
print(f"Cases where org:group is A or B:\n{filtered_log}")
# Out:
# Cases where org:group is A or B:
# [{'attributes': {'concept:name': 'A'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': True, 'SIRSCritTachypnea': True, 'Hypotensie': True, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 85, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 10, 22, 11, 15, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'A', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'A'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 11, 2, 15, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'A'}]}, '....', {'attributes': {'concept:name': 'KNA'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': True, 'concept:name': 'ER Registration', 'Age': 35, 'DiagnosticIC': True, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 11, 23, 28, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'QE', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'KNA'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 16, 17, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'KNA'}]}]

# %%
# This filter keeps the cases where the attribute 'Age' is not 85 as values
filtered_log = log_filters.filter_event_attribute_values('Age', [85], level="case", retain=False)
print(f"Cases where age is not 85:\n{filtered_log}")
# Out:
# Cases where age is not 85:
# [{'attributes': {'concept:name': 'B'}, 'events': [{'InfectionSuspected': True, 'org:group': 'A', 'DiagnosticBlood': True, 'DisfuncOrg': False, 'SIRSCritTachypnea': True, 'Hypotensie': False, 'SIRSCritHeartRate': True, 'Infusion': True, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 45, 'DiagnosticIC': True, 'DiagnosticSputum': True, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': True, 'DiagnosticXthorax': True, 'SIRSCritTemperature': True, 'time:timestamp': datetime.datetime(2014, 12, 21, 11, 4, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': True, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': True, 'lifecycle:transition': 'complete', 'Diagnose': 'B', 'Hypoxie': False, 'DiagnosticUrinarySediment': True, 'DiagnosticECG': True, 'case:concept:name': 'B'}, '..', {'org:group': 'E', 'lifecycle:transition': 'complete', 'concept:name': 'Release A', 'time:timestamp': datetime.datetime(2014, 12, 26, 18, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'B'}]}, '....', {'attributes': {'concept:name': 'LNA'}, 'events': [{'InfectionSuspected': False, 'org:group': 'L', 'DiagnosticBlood': False, 'DisfuncOrg': False, 'SIRSCritTachypnea': False, 'Hypotensie': False, 'SIRSCritHeartRate': False, 'Infusion': False, 'DiagnosticArtAstrup': False, 'concept:name': 'ER Registration', 'Age': 50, 'DiagnosticIC': False, 'DiagnosticSputum': False, 'DiagnosticLiquor': False, 'DiagnosticOther': False, 'SIRSCriteria2OrMore': False, 'DiagnosticXthorax': False, 'SIRSCritTemperature': False, 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 50, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'DiagnosticUrinaryCulture': False, 'SIRSCritLeucos': False, 'Oligurie': False, 'DiagnosticLacticAcid': False, 'lifecycle:transition': 'complete', 'Hypoxie': False, 'DiagnosticUrinarySediment': False, 'DiagnosticECG': False, 'case:concept:name': 'LNA'}, '..', {'org:group': 'L', 'lifecycle:transition': 'complete', 'concept:name': 'ER Sepsis Triage', 'time:timestamp': datetime.datetime(2014, 12, 3, 10, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'case:concept:name': 'LNA'}]}]
